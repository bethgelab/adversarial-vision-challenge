# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
file = np.load('26133692304_b24ed274d5_o.npy')

# %%
imshow(file)

# %%
file = np.load('26140597434_9b97423b9d_o.npy')

# %%
imshow(file)

# %%
file
# Out:
# array([[[186, 222, 255],
#         [187, 221, 255],
#         [187, 221, 255],
#         ...,
#         [ 43,  54,   0],
#         [147, 149, 109],
#         [149, 155,  57]],
#
#        [[188, 222, 255],
#         [188, 224, 255],
#         [187, 221, 255],
#         ...,
#         [ 86,  89,   0],
#         [ 85,  91,   3],
#         [104, 112,  75]],
#
#        [[188, 222, 255],
#         [187, 221, 255],
#         [187, 222, 255],
#         ...,
#         [150, 152,  55],
#         [ 47,  55,   6],
#         [113, 119,  13]],
#
#        ...,
#
#        [[ 58,  74,  89],
#         [ 69,  85,  98],
#         [ 71,  87, 103],
#         ...,
#         [ 73,  70,  15],
#         [ 80,  79,  33],
#         [ 82,  68,  19]],
#
#        [[ 66,  81,  88],
#         [ 78,  94, 107],
#         [ 68,  82,  85],
#         ...,
#         [ 80,  74,  26],
#         [ 82,  76,  14],
#         [105,  90,  31]],
#
#        [[ 79,  98, 112],
#         [ 68,  82,  91],
#         [ 68,  79,  83],
# ...

# %%
import os
for file in os.listdir('.'):
    if file[-3:] == 'npy':
        image = np.load(file)
        image = image * 255
        image = image.astype(np.uint8)
        np.save(file, image)
